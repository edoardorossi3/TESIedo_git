# %%
import numpy as np
import plot_spec
import astropy.io.fits as fits
import os

# %%
os.getenv('HOME')
# Out:
# '/export/home/extragal/erossi'

# %%
#par_file='/home/edoardo/Desktop/TESI/models/Sandage_v4.1_Zfix_noburst_cb16MILES_1M/sandage_varZ_v4.1_m62fix_noburst_1M_spec_dcombnull_001_physpar_wagef.fits'
suffix_file='sandage_varZ_v4.1_m62fix_noburst_1M_spec_dcombnull'

#hdul_par=fits.open(par_file)
#age50=hdul_par[1].data['age50']

plot_spec.spectre(suffix_file, 9.05, 9.1)
# Out:
# age50: 2748409300.0
# checkpoint 1
# size r: 1000000
# size i: 1000000
# d1090n50 limit tot: -0.6437499999999996
# d1090n50 limit idx: -0.6890625000000001
# d1090n50 limit col: -0.25781250000000006
# sigma_idx1: 0.03108398
# sigma_idx2: 0.22301795
# sigma_idx3: 0.04604625
# sigma_idx4: 0.0022159573
# sigma_idx5: 0.027197767
# sigma_col1: 0.06047537
# sigma_col2: 0.042515386
# sigma_col3: 0.043915257
# sigma_col4: 0.060261924
# first_row: 0 last_row: 208
# first_row: 208 last_row: 440
# first_row: 440 last_row: 660
# first_row: 660 last_row: 878
# first_row: 878 last_row: 1133
# first_row: 1133 last_row: 1372
# first_row: 1372 last_row: 1645
# first_row: 1645 last_row: 1880
# first_row: 1880 last_row: 2120
# first_row: 2120 last_row: 2371
# first_row: 2371 last_row: 2601
# first_row: 2601 last_row: 2860
# first_row: 2860 last_row: 3079
# first_row: 3079 last_row: 3324
# first_row: 3324 last_row: 3569
# first_row: 3569 last_row: 3835
# first_row: 3835 last_row: 4082
# ...

# %%
#bin_age50=np.histogram(np.log10(age50), 83, range=(6.0, 10.15))[1]
#for i in range(0, 83):
#    plot_spec.spectre(suffix_file, bin_age50[i], bin_age50[i+1])
