# %%
import numpy as np
import plot_spec
import astropy.io.fits as fits

# %%
par_file='/home/edoardo/Desktop/TESI/models/Sandage_v4.1_Zfix_noburst_cb16MILES_1M/sandage_varZ_v4.1_m62fix_noburst_1M_spec_dcombnull_001_physpar_wagef.fits'
suffix_file='sandage_varZ_v4.1_m62fix_noburst_1M_spec_dcombnull'

hdul_par=fits.open(par_file)
age50=hdul_par[1].data['age50']

plot_spec.spectre(suffix_file, 8.85, 9.1)
# Out:
# 20000
# 1180
# d1090n50 limit tot: -0.040624999999999696
# d1090n50 limit idx: -0.042187500000000024
# d1090n50 limit col: -0.042187500000000024
# sigma_idx1: 0.04784537
# sigma_idx2: 3.630503
# sigma_idx3: 0.645362
# sigma_idx4: 0.025179917
# sigma_idx5: 0.17119104
# sigma_col1: 0.12757872
# sigma_col2: 0.086006284
# sigma_col3: 0.050780453
# sigma_col4: 0.08421973

# %%
#bin_age50=np.histogram(np.log10(age50), 83, range=(6.0, 10.15))[1]
#for i in range(0, 83):
#    plot_spec.spectre(suffix_file, bin_age50[i], bin_age50[i+1])
