# %%
import numpy as np
import plot_spec
import astropy.io.fits as fits
import os

# %%
os.getenv('HOME')
# Out:
# '/export/home/extragal/erossi'

# %%
#par_file='/home/edoardo/Desktop/TESI/models/Sandage_v4.1_Zfix_noburst_cb16MILES_1M/sandage_varZ_v4.1_m62fix_noburst_1M_spec_dcombnull_001_physpar_wagef.fits'
suffix_file='sandage_varZ_v4.1_m62fix_noburst_1M_spec_dcombnull'

#hdul_par=fits.open(par_file)
#age50=hdul_par[1].data['age50']

fig_specm62_8=plot_spec.spectre(suffix_file, 8.0, 8.05)
# Out:
# age50: 2748409300.0
# checkpoint 1
# size r: 1000000
# size i: 1000000
# d1090n50 limit tot: -0.1859374999999997
# d1090n50 limit idx: -0.18593750000000003
# d1090n50 limit col: 0.029687499999999985
# sigma_idx1: 0.030263836
# sigma_idx2: 0.20618598
# sigma_idx3: 0.07509976
# sigma_idx4: 0.004679305
# sigma_idx5: 0.015929617
# sigma_col1: 0.05853669
# sigma_col2: 0.043008186
# sigma_col3: 0.042275406
# sigma_col4: 0.058975738
# first_row: 0 last_row: 245
# first_row: 245 last_row: 474
# first_row: 474 last_row: 719
# first_row: 719 last_row: 936
# first_row: 936 last_row: 1180
# first_row: 1180 last_row: 1432
# first_row: 1432 last_row: 1676
# first_row: 1676 last_row: 1954
# first_row: 1954 last_row: 2208
# first_row: 2208 last_row: 2458
# first_row: 2458 last_row: 2697
# first_row: 2697 last_row: 2979
# first_row: 2979 last_row: 3209
# first_row: 3209 last_row: 3449
# first_row: 3449 last_row: 3690
# first_row: 3690 last_row: 3899
# first_row: 3899 last_row: 4141
# ...

# %%
#fig_specm62_8.savefig('/export/home/extragal/erossi/ownCloud/TESI/figure/specm62_8.png')

# %%
#8.5, 9.0, 9.5, 10 m62
#9.0 m42

# %%
fig_d4000n_hd_m62_8=plot_spec.spec_indices(suffix_file, 8.0, 8.05, [3850,4100], [4041,4161],[3850,3900,3900,3950],[4041,4080,4128,4161],title1=r'$D4000n$',title2=r'$H-\delta$')
fig_hg_hb_m62_8=plot_spec.spec_indices(suffix_file, 8.0, 8.05, [4283,4420], [4827,4892],[4283,4320,4367,4420],[4827,4848,4877,4892],title1=r'$H-\gamma$',title2=r'$H-\beta$')
fig_mg2_fe5270_m62_8=plot_spec.spec_indices(suffix_file, 8.0, 8.05, [4895,5367], [5233,5319],[4895,4957,5302,5366],[5233,5248,5286,5319],title1=r'$Mg_{2}$',title2=r'$Fe5270$')
# Out:
# age50: 2748409300.0
# checkpoint 1
# size r: 1000000
# size i: 1000000
# d1090n50 limit tot: -0.1859374999999997
# d1090n50 limit idx: -0.18593750000000003
# d1090n50 limit col: 0.029687499999999985
# sigma_idx1: 0.030263836
# sigma_idx2: 0.20618598
# sigma_idx3: 0.07509976
# sigma_idx4: 0.004679305
# sigma_idx5: 0.015929617
# sigma_col1: 0.05853669
# sigma_col2: 0.043008186
# sigma_col3: 0.042275406
# sigma_col4: 0.058975738
# first_row: 0 last_row: 245
# first_row: 245 last_row: 474
# first_row: 474 last_row: 719
# first_row: 719 last_row: 936
# first_row: 936 last_row: 1180
# first_row: 1180 last_row: 1432
# first_row: 1432 last_row: 1676
# first_row: 1676 last_row: 1954
# first_row: 1954 last_row: 2208
# first_row: 2208 last_row: 2458
# first_row: 2458 last_row: 2697
# first_row: 2697 last_row: 2979
# first_row: 2979 last_row: 3209
# first_row: 3209 last_row: 3449
# first_row: 3449 last_row: 3690
# first_row: 3690 last_row: 3899
# first_row: 3899 last_row: 4141
# ...

# %%
#fig_d4000n_hd_m62_8.savefig('/export/home/extragal/erossi/ownCloud/TESI/figure/d4000nhdm62_8.png')
#fig_hg_hb_m62_8.savefig('/export/home/extragal/erossi/ownCloud/TESI/figure/hghbm62_8.png')
#fig_mg2_fe5270_m62_8.savefig('/export/home/extragal/erossi/ownCloud/TESI/figure/mg2fe5270m62_8.png')

# %%
import matplotlib.pyplot as plt
import matplotlib.colorbar as clb
import matplotlib.cm as cm


fig = plt.figure()
gs = fig.add_gridspec(2, 2, height_ratios=[1., 1.], width_ratios=[5,0.5], hspace=0.2, wspace=0.8)
ax1 = fig.add_subplot(gs[0, 0])
ax2 = fig.add_subplot(gs[1, 0])
# spans two rows:
ax3 = fig.add_subplot(gs[:, 1])
clb.ColorbarBase(ax3, cmap=cm.rainbow_r)
#bbox_props = dict( fc="w", ec="k", lw=2)


#ax3.annotate(r'$\rightarrow$',
#xy=(0, 0.5),
#xycoords='data',
#horizontalalignment='right',
#verticalalignment='top',
#bbox=bbox_props)
ax3.annotate('S/N=200',
xy=(0, 0.5),
xycoords='data',
xytext=(-1, 0.5),
arrowprops=
dict(facecolor='red', shrink=0),
horizontalalignment='right',
verticalalignment='center', size=13)



#ax1.get_xaxis().set_visible(False)
# Out:
# Text(-1, 0.5, 'S/N=200')
