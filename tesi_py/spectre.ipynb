# %%
import numpy as np
import plot_spec

# %%
name_file='sandage_varZ_v4.1_m62fix_noburst_1M_spec_dcombnull_001.fits'
par_file='sandage_varZ_v4.1_m62fix_noburst_1M_spec_dcombnull_001_physpar_wagef.fits'
suffix_file='sandage_varZ_v4.1_m62fix_noburst_1M_spec_dcombnull_001'

plot_spec.spectre(suffix_file, 7.0, 7.05)

# %%
len(name_file)
# Out:
# 59

# %%
np.where(name_file == par_file)
# Out:
# (array([], dtype=int64),)
