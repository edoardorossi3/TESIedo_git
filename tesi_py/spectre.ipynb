# %%
import numpy as np
import plot_spec
import astropy.io.fits as fits
import os

# %%
os.getenv('HOME')
# Out:
# '/export/home/extragal/erossi'

# %%
#par_file='/home/edoardo/Desktop/TESI/models/Sandage_v4.1_Zfix_noburst_cb16MILES_1M/sandage_varZ_v4.1_m62fix_noburst_1M_spec_dcombnull_001_physpar_wagef.fits'
suffix_file='sandage_varZ_v4.1_m62fix_noburst_1M_spec_dcombnull'

#hdul_par=fits.open(par_file)
#age50=hdul_par[1].data['age50']

fig_specm62_8=plot_spec.spectre(suffix_file, 9.5, 9.55, dage_n_max=0.0)
# Out:
# age50: 2748409300.0
# checkpoint 1
# size r: 1000000
# size i: 1000000
# d1090n50 limit tot: -0.5249999999999996
# d1090n50 limit idx: -0.5453125000000001
# d1090n50 limit col: -0.18593750000000003
# sigma_idx1: 0.031107387
# sigma_idx2: 0.12823232
# sigma_idx3: 0.017882654
# sigma_idx4: 0.0013701373
# sigma_idx5: 0.022475818
# sigma_col1: 0.058336947
# sigma_col2: 0.042854246
# sigma_col3: 0.042731237
# sigma_col4: 0.059418183
# first_row: 0 last_row: 169
# first_row: 169 last_row: 308
# first_row: 308 last_row: 447
# first_row: 447 last_row: 583
# first_row: 583 last_row: 731
# first_row: 731 last_row: 900
# first_row: 900 last_row: 1048
# first_row: 1048 last_row: 1195
# first_row: 1195 last_row: 1333
# first_row: 1333 last_row: 1483
# first_row: 1483 last_row: 1627
# first_row: 1627 last_row: 1791
# first_row: 1791 last_row: 1929
# first_row: 1929 last_row: 2073
# first_row: 2073 last_row: 2231
# first_row: 2231 last_row: 2397
# first_row: 2397 last_row: 2551
# ...

# %%
#fig_specm62_8.savefig('/export/home/extragal/erossi/ownCloud/TESI/figure/specm62_95_dage_lt_0.png')

# %%
#8.5, 9.0, 9.5, 10 m62
#9.0 m42

# %%
fig_d4000n_hd_m62_8=plot_spec.spec_indices(suffix_file, 9.5, 9.55, [3850,4100], [4041,4161],[3850,3900,3900,3950],[4041,4080,4128,4161],title1=r'$D4000n$',title2=r'$H\delta_A$')
fig_hg_hb_m62_8=plot_spec.spec_indices(suffix_file, 9.5, 9.55, [4283,4420], [4827,4892],[4283,4320,4367,4420],[4827,4848,4877,4892],title1=r'$H\gamma_A$',title2=r'$H\beta$')
fig_mg2_fe5270_m62_8=plot_spec.spec_indices(suffix_file, 9.5, 9.55, [4895,5367], [5233,5319],[4895,4957,5302,5366],[5233,5248,5286,5319],title1=r'$Mg_{2}$',title2=r'$Fe5270$')
# Out:
# age50: 2748409300.0
# checkpoint 1
# size r: 1000000
# size i: 1000000
# d1090n50 limit tot: -0.5249999999999996
# d1090n50 limit idx: -0.5453125000000001
# d1090n50 limit col: -0.18593750000000003
# sigma_idx1: 0.031107387
# sigma_idx2: 0.12823232
# sigma_idx3: 0.017882654
# sigma_idx4: 0.0013701373
# sigma_idx5: 0.022475818
# sigma_col1: 0.058336947
# sigma_col2: 0.042854246
# sigma_col3: 0.042731237
# sigma_col4: 0.059418183
# first_row: 0 last_row: 257
# first_row: 257 last_row: 492
# first_row: 492 last_row: 720
# first_row: 720 last_row: 944
# first_row: 944 last_row: 1176
# first_row: 1176 last_row: 1452
# first_row: 1452 last_row: 1692
# first_row: 1692 last_row: 1928
# first_row: 1928 last_row: 2162
# first_row: 2162 last_row: 2407
# first_row: 2407 last_row: 2648
# first_row: 2648 last_row: 2905
# first_row: 2905 last_row: 3140
# first_row: 3140 last_row: 3378
# first_row: 3378 last_row: 3617
# first_row: 3617 last_row: 3886
# first_row: 3886 last_row: 4124
# ...

# %%
save=True
if save:
    fig_specm62_8.savefig('/export/home/extragal/erossi/ownCloud/TESI/figure/specm62_95.png')
    fig_d4000n_hd_m62_8.savefig('/export/home/extragal/erossi/ownCloud/TESI/figure/d4000nhdm62_95.png')
    fig_hg_hb_m62_8.savefig('/export/home/extragal/erossi/ownCloud/TESI/figure/hghbm62_95.png')
    fig_mg2_fe5270_m62_8.savefig('/export/home/extragal/erossi/ownCloud/TESI/figure/mg2fe5270m62_95.png')

# %%
import matplotlib.pyplot as plt
import matplotlib.colorbar as clb
import matplotlib.cm as cm


fig = plt.figure()
gs = fig.add_gridspec(2, 2, height_ratios=[1., 1.], width_ratios=[5,0.5], hspace=0.2, wspace=0.8)
ax1 = fig.add_subplot(gs[0, 0])
ax2 = fig.add_subplot(gs[1, 0])
# spans two rows:
ax3 = fig.add_subplot(gs[:, 1])
clb.ColorbarBase(ax3, cmap=cm.rainbow_r)
#bbox_props = dict( fc="w", ec="k", lw=2)


#ax3.annotate(r'$\rightarrow$',
#xy=(0, 0.5),
#xycoords='data',
#horizontalalignment='right',
#verticalalignment='top',
#bbox=bbox_props)
ax3.annotate('S/N=200',
xy=(0, 0.5),
xycoords='data',
xytext=(-1, 0.5),
arrowprops=
dict(facecolor='red', shrink=0),
horizontalalignment='right',
verticalalignment='center', size=13)



#ax1.get_xaxis().set_visible(False)
