# %%
import os
import astropy.io.fits as fits
import function_plot as f_plt
import numpy as np
import matplotlib.pyplot as plt

# %%
mock_snr5_dir=os.getenv('HOME')+'/Desktop/TESI/models/Sandage_varZ_v4.2eq_CB16MILES_ChFall/mock_ER_snr5/'
mock_snr10_dir=os.getenv('HOME')+'/Desktop/TESI/models/Sandage_varZ_v4.2eq_CB16MILES_ChFall/mock_ER_snr10/'
mock_snr20_dir=os.getenv('HOME')+'/Desktop/TESI/models/Sandage_varZ_v4.2eq_CB16MILES_ChFall/mock_ER_snr20/'
mock_snr50_dir=os.getenv('HOME')+'/Desktop/TESI/models/Sandage_varZ_v4.2eq_CB16MILES_ChFall/mock_ER_snr50/'
mock_snr100_dir=os.getenv('HOME')+'/Desktop/TESI/models/Sandage_varZ_v4.2eq_CB16MILES_ChFall/mock_ER_snr100/'

models_dir=os.getenv('HOME')+'/Desktop/TESI/models/Sandage_varZ_v4.2eq_CB16MILES_ChFall/'

# %%
file_mocksnr5_dage1090n50=mock_snr5_dir+'mock_file_dage_10_90n50001.fits'
file_mocksnr10_dage1090n50=mock_snr10_dir+'mock_file_dage_10_90n50001.fits'
file_mocksnr20_dage1090n50=mock_snr20_dir+'mock_file_dage_10_90n50001.fits'
file_mocksnr50_dage1090n50=mock_snr50_dir+'mock_file_dage_10_90n50001.fits'
file_mocksnr100_dage1090n50=mock_snr100_dir+'mock_file_dage_10_90n50001.fits'

file_par=models_dir+'sandage_varZ_v4.2eq_spec_dcomb0p25null_001_physpar_wagef.fits'
file_idx=models_dir+'sandage_varZ_v4.2eq_spec_dcomb0p25null_idx_001.fits'
file_pertsnr5=models_dir+'sandage_varZ_v4.2eq_spec_dcomb0p25null_perterr_SNR5_001.fits'
file_pertsnr10=models_dir+'sandage_varZ_v4.2eq_spec_dcomb0p25null_perterr_SNR10_001.fits'
file_pertsnr20=models_dir+'sandage_varZ_v4.2eq_spec_dcomb0p25null_perterr_001.fits'
file_pertsnr50=models_dir+'sandage_varZ_v4.2eq_spec_dcomb0p25null_perterr_SNR50_001.fits'
file_pertsnr100=models_dir+'sandage_varZ_v4.2eq_spec_dcomb0p25null_perterr_SNR100_001.fits'

# %%
hdul_dage1090n50_snr5=fits.open(file_mocksnr5_dage1090n50)
hdul_dage1090n50_snr10=fits.open(file_mocksnr10_dage1090n50)
hdul_dage1090n50_snr20=fits.open(file_mocksnr20_dage1090n50)
hdul_dage1090n50_snr50=fits.open(file_mocksnr50_dage1090n50)
hdul_dage1090n50_snr100=fits.open(file_mocksnr100_dage1090n50)

hdul_par=fits.open(file_par)
hdul_idx=fits.open(file_idx)
hdul_pertsnr5=fits.open(file_pertsnr5)
hdul_pertsnr10=fits.open(file_pertsnr10)
hdul_pertsnr20=fits.open(file_pertsnr20)
hdul_pertsnr50=fits.open(file_pertsnr50)
hdul_pertsnr100=fits.open(file_pertsnr100)

# %%
age10=hdul_par[1].data['age10']
age25=hdul_par[1].data['age25']
age50=hdul_par[1].data['age50']
age75=hdul_par[1].data['age75']
age90=hdul_par[1].data['age90']
dage1090n50=(age10-age90)/age50

hdhg=hdul_idx[1].data['HdHg'][...,4] 
D4000n=hdul_idx[1].data['D4000n'][...,4]
mg2fe=hdul_idx[1].data['MG2FE'][...,4]
D4000n_err_snr5=hdul_pertsnr5[1].data['D4000N_ERR_SNR020']
hdhg_err_snr5=hdul_pertsnr5[1].data['HDHG_ERR_SNR020']
mg2fe_err_snr5=hdul_pertsnr5[1].data['MG2FE_ERR_SNR020']
D4000n_err_snr10=hdul_pertsnr10[1].data['D4000N_ERR_SNR020']
hdhg_err_snr10=hdul_pertsnr10[1].data['HDHG_ERR_SNR020']
mg2fe_err_snr10=hdul_pertsnr10[1].data['MG2FE_ERR_SNR020']
D4000n_err_snr20=hdul_pertsnr20[1].data['D4000N_ERR_SNR020']
hdhg_err_snr20=hdul_pertsnr20[1].data['HDHG_ERR_SNR020']
mg2fe_err_snr20=hdul_pertsnr20[1].data['MG2FE_ERR_SNR020']
D4000n_err_snr50=hdul_pertsnr50[1].data['D4000N_ERR_SNR020']
hdhg_err_snr50=hdul_pertsnr50[1].data['HDHG_ERR_SNR020']
mg2fe_err_snr50=hdul_pertsnr50[1].data['MG2FE_ERR_SNR020']
D4000n_err_snr100=hdul_pertsnr100[1].data['D4000N_ERR_SNR020']
hdhg_err_snr100=hdul_pertsnr100[1].data['HDHG_ERR_SNR020']
mg2fe_err_snr100=hdul_pertsnr100[1].data['MG2FE_ERR_SNR020']

dage1090n50_snr5=hdul_dage1090n50_snr5[1].data['PARAM_MEDIAN']
dage1090n50_err_snr5=(np.log10(hdul_dage1090n50_snr5[1].data['PARAM_P84'])-np.log10(hdul_dage1090n50_snr5[1].data['PARAM_P16']))/2.0
dage1090n50_snr10=hdul_dage1090n50_snr10[1].data['PARAM_MEDIAN']
dage1090n50_err_snr10=(np.log10(hdul_dage1090n50_snr10[1].data['PARAM_P84'])-np.log10(hdul_dage1090n50_snr10[1].data['PARAM_P16']))/2.0
dage1090n50_snr20=hdul_dage1090n50_snr20[1].data['PARAM_MEDIAN']
dage1090n50_err_snr20=(np.log10(hdul_dage1090n50_snr20[1].data['PARAM_P84'])-np.log10(hdul_dage1090n50_snr20[1].data['PARAM_P16']))/2.0
dage1090n50_snr50=hdul_dage1090n50_snr50[1].data['PARAM_MEDIAN']
dage1090n50_err_snr50=(np.log10(hdul_dage1090n50_snr50[1].data['PARAM_P84'])-np.log10(hdul_dage1090n50_snr50[1].data['PARAM_P16']))/2.0
dage1090n50_snr100=hdul_dage1090n50_snr100[1].data['PARAM_MEDIAN']
dage1090n50_err_snr100=(np.log10(hdul_dage1090n50_snr100[1].data['PARAM_P84'])-np.log10(hdul_dage1090n50_snr100[1].data['PARAM_P16']))/2.0

# %%
#std_mock, bias_par.statistic, np.sqrt(mean2diff_bias.statistic), median_bayes_err.statistic
std_mock_snr5, bias_par_snr5, mean2diff_snr5, bay_err_snr5, d4000n_g, hdhg_g=f_plt.density_map_5p(D4000n, hdhg, np.log10(dage1090n50), np.log10(dage1090n50_snr5), (dage1090n50_err_snr5),D4000n_err_snr5, hdhg_err_snr5,par_name=r'$\log(\Delta age_{10,90}/age_{50})$', x_label='D4000n', y_label='HdHg', vmin=[-1.0,0.06, -0.3, 0.06,0.06], vmax=[1.5,0.8, 0.3, 0.8,0.8], figsize=(27,24), s=1, statistic=True)
# Out:
# total deleted (no finite values): 0

# %%
std_mock_snr10, bias_par_snr10, mean2diff_snr10, bay_err_snr10, d4000n_g, hdhg_g=f_plt.density_map_5p(D4000n, hdhg, np.log10(dage1090n50), np.log10(dage1090n50_snr10), (dage1090n50_err_snr10),D4000n_err_snr10, hdhg_err_snr10,par_name=r'$\log(\Delta age_{10,90}/age_{50})$', x_label='D4000n', y_label='HdHg', vmin=[-1.0,0.06, -0.3, 0.06,0.06], vmax=[1.5,0.8, 0.3, 0.8,0.8], figsize=(27,24), s=1, statistic=True)
# Out:
# total deleted (no finite values): 0

# %%
std_mock_snr20, bias_par_snr20, mean2diff_snr20, bay_err_snr20, d4000n_g, hdhg_g=f_plt.density_map_5p(D4000n, hdhg, np.log10(dage1090n50), np.log10(dage1090n50_snr20), (dage1090n50_err_snr20),D4000n_err_snr20, hdhg_err_snr20,par_name=r'$\log(\Delta age_{10,90}/age_{50})$', x_label='D4000n', y_label='HdHg', vmin=[-1.0,0.06, -0.3, 0.06,0.06], vmax=[1.5,0.8, 0.3, 0.8,0.8], figsize=(27,24), s=1,statistic=True)
# Out:
# total deleted (no finite values): 0
# /home/edoardo/Desktop/TESIedo_git/tesi_py/function_plot.py:93: RuntimeWarning: divide by zero encountered in true_divide
#   err_norm=stats.binned_statistic_2d(x_fin,y_fin,(mock_par-par)/(mock_err), bins=N_bins, statistic=function_plot.rms_1684)
# /home/edoardo/anaconda3/lib/python3.8/site-packages/numpy/lib/function_base.py:3968: RuntimeWarning: invalid value encountered in multiply
#   x2 = take(ap, indices_above, axis=axis) * weights_above

# %%
std_mock_snr50, bias_par_snr50, mean2diff_snr50, bay_err_snr50, d4000n_g, hdhg_g=f_plt.density_map_5p(D4000n, hdhg, np.log10(dage1090n50), np.log10(dage1090n50_snr50), (dage1090n50_err_snr50),D4000n_err_snr50, hdhg_err_snr50,par_name=r'$\log(\Delta age_{10,90}/age_{50})$', x_label='D4000n', y_label='HdHg', vmin=[-1.0,0.06, -0.3, 0.06,0.06], vmax=[1.5,0.8, 0.3, 0.8,0.8], figsize=(27,24), s=1, statistic=True)
# Out:
# total deleted (no finite values): 0
# /home/edoardo/Desktop/TESIedo_git/tesi_py/function_plot.py:93: RuntimeWarning: divide by zero encountered in true_divide
#   err_norm=stats.binned_statistic_2d(x_fin,y_fin,(mock_par-par)/(mock_err), bins=N_bins, statistic=function_plot.rms_1684)
# /home/edoardo/anaconda3/lib/python3.8/site-packages/numpy/lib/function_base.py:3968: RuntimeWarning: invalid value encountered in multiply
#   x2 = take(ap, indices_above, axis=axis) * weights_above

# %%
std_mock_snr100, bias_par_snr100, mean2diff_snr100, bay_err_snr100, d4000n_g, hdhg_g=f_plt.density_map_5p(D4000n, hdhg, np.log10(dage1090n50), np.log10(dage1090n50_snr100), (dage1090n50_err_snr100),D4000n_err_snr100, hdhg_err_snr100,par_name=r'$\log(\Delta age_{10,90}/age_{50})$', x_label='D4000n', y_label='HdHg', vmin=[-1.0,0.06, -0.3, 0.06,0.06], vmax=[1.5,0.8, 0.3, 0.8,0.8], figsize=(27,24), s=1, statistic=True)
# Out:
# total deleted (no finite values): 0
# /home/edoardo/Desktop/TESIedo_git/tesi_py/function_plot.py:93: RuntimeWarning: divide by zero encountered in true_divide
#   err_norm=stats.binned_statistic_2d(x_fin,y_fin,(mock_par-par)/(mock_err), bins=N_bins, statistic=function_plot.rms_1684)
# /home/edoardo/anaconda3/lib/python3.8/site-packages/numpy/lib/function_base.py:3968: RuntimeWarning: invalid value encountered in multiply
#   x2 = take(ap, indices_above, axis=axis) * weights_above

# %%
fig, axs=plt.subplots(1, 4, figsize=(20,5))
im1=axs[0].pcolormesh(d4000n_g, hdhg_g, mean2diff_snr5-mean2diff_snr20, vmin=-0.08, vmax=0.08)
fig.colorbar(im1, ax=axs)
im2=axs[1].pcolormesh(d4000n_g, hdhg_g, mean2diff_snr10-mean2diff_snr20, vmin=-0.08, vmax=0.08)
im3=axs[2].pcolormesh(d4000n_g, hdhg_g, mean2diff_snr50-mean2diff_snr20, vmin=-0.08, vmax=0.08)
im4=axs[3].pcolormesh(d4000n_g, hdhg_g, mean2diff_snr100-mean2diff_snr20, vmin=-0.08, vmax=0.08)
axs[0].set_title('mean2diff_snr5-mean2diff_snr20')
axs[1].set_title('mean2diff_snr10-mean2diff_snr20')
axs[2].set_title('mean2diff_snr50-mean2diff_snr20')
axs[3].set_title('mean2diff_snr100-mean2diff_snr20')
# Out:
# Text(0.5, 1.0, 'mean2diff_snr100-mean2diff_snr20')

# %%
fig, axs=plt.subplots(1, 5, figsize=(20,5))
im1=axs[0].pcolormesh(d4000n_g, hdhg_g, bias_par_snr5, vmin=-0.08, vmax=0.08)
fig.colorbar(im1, ax=axs)
im2=axs[1].pcolormesh(d4000n_g, hdhg_g, bias_par_snr10, vmin=-0.08, vmax=0.08)
im3=axs[2].pcolormesh(d4000n_g, hdhg_g, bias_par_snr20, vmin=-0.08, vmax=0.08)
im4=axs[3].pcolormesh(d4000n_g, hdhg_g, bias_par_snr50, vmin=-0.08, vmax=0.08)
im5=axs[4].pcolormesh(d4000n_g, hdhg_g, bias_par_snr100, vmin=-0.08, vmax=0.08)

axs[0].set_title('bias_par_snr5')
axs[1].set_title('bias_par_snr10')
axs[2].set_title('bias_par_snr20')
axs[3].set_title('bias_par_snr50')
axs[4].set_title('bias_par_snr100')
# Out:
# Text(0.5, 1.0, 'bias_par_snr100')
